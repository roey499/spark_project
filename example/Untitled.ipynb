# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row

spark = SparkSession.builder.master('local[*]').appName('example_app').getOrCreate()

example_data = [Row('one'), Row('two'), Row('three'), Row('four')]
cols = ['my_col']

data_df = spark.createDataFrame(data=example_data, schema=cols)

data_df.show()

spark.stop()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/07/14 16:29:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +------+
# |my_col|
# +------+
# |   one|
# |   two|
# | three|
# |  four|
# +------+
