# %%
from pyspark.sql import Row
from spark_session_config import spark_cars
from schema import car_colors_schema

car_colors = [
    Row(color_id=1, color_name="Black"),
    Row(color_id=2, color_name="Red"),
    Row(color_id=3, color_name="Gray"),
    Row(color_id=4, color_name="White"),
    Row(color_id=5, color_name="Green"),
    Row(color_id=6, color_name="Blue"),
    Row(color_id=7, color_name="Pink")
]
models_df = spark_cars.createDataFrame(car_colors, schema=car_colors_schema)

models_df.write.parquet("s3a://pyspark/data/dims/car_colors",mode = "overwrite")

spark_cars.stop()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/08/15 17:18:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/08/15 17:18:17 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# 26/08/15 17:18:17 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# 26/08/15 17:18:19 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
