# %%
from pyspark.sql import Row
from spark_session_config import spark_cars
from schema import car_models_schema

Car_Models = [
    Row(model_id=1, car_brand="Mazda", car_model="3"),
    Row(model_id=2, car_brand="Mazda", car_model="6"),
    Row(model_id=3, car_brand="Toyota", car_model="Corolla"),
    Row(model_id=4, car_brand="Hyundai", car_model="i20"),
    Row(model_id=5, car_brand="Kia", car_model="Sportage"),
    Row(model_id=6, car_brand="Kia", car_model="Rio"),
    Row(model_id=7, car_brand="Kia", car_model="Picanto")
]

models_df = spark_cars.createDataFrame(Car_Models, schema=car_models_schema)

models_df.write.parquet("s3a://pyspark/data/dims/car_models",mode = "overwrite")

spark_cars.stop()
# Out:
# 26/08/15 16:06:35 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
